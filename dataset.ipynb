# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl (16.3 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Define the dataset
data = [
    {"State Name": "Andhra Pradesh", "Popular Food of the State": "Pongal", "Population of the State": 53215500, "Land Area": 162968, "Capital City": "Amaravati", "Gender Ratio": 993},
    {"State Name": "Arunachal Pradesh", "Popular Food of the State": "Thukpa", "Population of the State": 1383727, "Land Area": 83743, "Capital City": "Itanagar", "Gender Ratio": 920},
    {"State Name": "Assam", "Popular Food of the State": "Assamese Thali", "Population of the State": 31169272, "Land Area": 78438, "Capital City": "Dispur", "Gender Ratio": 958},
    {"State Name": "Bihar", "Popular Food of the State": "Litti Chokha", "Population of the State": 104099452, "Land Area": 94163, "Capital City": "Patna", "Gender Ratio": 918},
    {"State Name": "Chhattisgarh", "Popular Food of the State": "Chana Samosa", "Population of the State": 25545198, "Land Area": 135191, "Capital City": "Raipur", "Gender Ratio": 991},
    {"State Name": "Goa", "Popular Food of the State": "Goan Fish Curry", "Population of the State": 1457723, "Land Area": 3702, "Capital City": "Panaji", "Gender Ratio": 968},
    {"State Name": "Gujarat", "Popular Food of the State": "Dhokla", "Population of the State": 67808256, "Land Area": 196024, "Capital City": "Gandhinagar", "Gender Ratio": 919},
    {"State Name": "Haryana", "Popular Food of the State": "Hara Dhania Cholia", "Population of the State": 25353081, "Land Area": 44212, "Capital City": "Chandigarh", "Gender Ratio": 879},
    {"State Name": "Himachal Pradesh", "Popular Food of the State": "Chana Madra", "Population of the State": 6864602, "Land Area": 55673, "Capital City": "Shimla", "Gender Ratio": 974},
    {"State Name": "Jharkhand", "Popular Food of the State": "Litti Chokha", "Population of the State": 32988134, "Land Area": 79714, "Capital City": "Ranchi", "Gender Ratio": 948},
    {"State Name": "Karnataka", "Popular Food of the State": "Bisi Bele Bath", "Population of the State": 61095297, "Land Area": 191791, "Capital City": "Bengaluru", "Gender Ratio": 973},
    {"State Name": "Kerala", "Popular Food of the State": "Sadya", "Population of the State": 33406061, "Land Area": 38863, "Capital City": "Thiruvananthapuram", "Gender Ratio": 1084},
    {"State Name": "Madhya Pradesh", "Popular Food of the State": "Poha", "Population of the State": 72626809, "Land Area": 308350, "Capital City": "Bhopal", "Gender Ratio": 931},
    {"State Name": "Maharashtra", "Popular Food of the State": "Puran Poli", "Population of the State": 112374333, "Land Area": 307713, "Capital City": "Mumbai", "Gender Ratio": 925},
    {"State Name": "Manipur", "Popular Food of the State": "Singju", "Population of the State": 2855794, "Land Area": 22327, "Capital City": "Imphal", "Gender Ratio": 985},
    {"State Name": "Meghalaya", "Popular Food of the State": "Jadoh", "Population of the State": 2966889, "Land Area": 22429, "Capital City": "Shillong", "Gender Ratio": 989},
    {"State Name": "Mizoram", "Popular Food of the State": "Bai", "Population of the State": 1091014, "Land Area": 21081, "Capital City": "Aizawl", "Gender Ratio": 976},
    {"State Name": "Nagaland", "Popular Food of the State": "Pork with Bamboo Shoot", "Population of the State": 1978502, "Land Area": 16579, "Capital City": "Kohima", "Gender Ratio": 931},
    {"State Name": "Odisha", "Popular Food of the State": "Pakhala Bhata", "Population of the State": 41974218, "Land Area": 155707, "Capital City": "Bhubaneswar", "Gender Ratio": 979},
    {"State Name": "Punjab", "Popular Food of the State": "Butter Chicken", "Population of the State": 27743338, "Land Area": 50362, "Capital City": "Chandigarh", "Gender Ratio": 895},
    {"State Name": "Rajasthan", "Popular Food of the State": "Dal Baati Churma", "Population of the State": 68548437, "Land Area": 342239, "Capital City": "Jaipur", "Gender Ratio": 928},
    {"State Name": "Sikkim", "Popular Food of the State": "Phagshapa", "Population of the State": 610577, "Land Area": 7096, "Capital City": "Gangtok", "Gender Ratio": 889},
    {"State Name": "Tamil Nadu", "Popular Food of the State": "Idli Dosa", "Population of the State": 72147030, "Land Area": 130058, "Capital City": "Chennai", "Gender Ratio": 996},
    {"State Name": "Telangana", "Popular Food of the State": "Hyderabadi Biryani", "Population of the State": 38505918, "Land Area": 114840, "Capital City": "Hyderabad", "Gender Ratio": 988},
    {"State Name": "Tripura", "Popular Food of the State": "Mui Borok", "Population of the State": 3671032, "Land Area": 10486, "Capital City": "Agartala", "Gender Ratio": 964},
    {"State Name": "Uttar Pradesh", "Popular Food of the State": "Chaat", "Population of the State": 199812341, "Land Area": 243286, "Capital City": "Lucknow", "Gender Ratio": 912},
    {"State Name": "Uttarakhand", "Popular Food of the State": "Aloo Keema", "Population of the State": 10116752, "Land Area": 53483, "Capital City": "Dehradun", "Gender Ratio": 963},
    {"State Name": "West Bengal", "Popular Food of the State": "Macher Jhol", "Population of the State": 91276115, "Land Area": 88752, "Capital City": "Kolkata", "Gender Ratio": 950}
]

df = pd.DataFrame(data)

csv_file = 'indian_states_dataset.csv'
df.to_csv(csv_file, index=False)

# %%
df
# Out:
#            State Name Popular Food of the State  Population of the State  \
# 0      Andhra Pradesh                    Pongal                 53215500
# 1   Arunachal Pradesh                    Thukpa                  1383727
# 2               Assam            Assamese Thali                 31169272
# 3               Bihar              Litti Chokha                104099452
# 4        Chhattisgarh              Chana Samosa                 25545198
# 5                 Goa           Goan Fish Curry                  1457723
# 6             Gujarat                    Dhokla                 67808256
# 7             Haryana        Hara Dhania Cholia                 25353081
# 8    Himachal Pradesh               Chana Madra                  6864602
# 9           Jharkhand              Litti Chokha                 32988134
# 10          Karnataka            Bisi Bele Bath                 61095297
# 11             Kerala                     Sadya                 33406061
# ...
